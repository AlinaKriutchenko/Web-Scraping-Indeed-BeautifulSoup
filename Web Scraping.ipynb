# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime

# %%
def extract(page):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}
    link = 'https://au.indeed.com/jobs?q=Data+Scientist&l=Melbourne+VIC&radius=50&sort=date'
    r = requests.get(link, headers)
    soup = BeautifulSoup(r.content, 'html.parser')
    return soup

# %%
def transform(soup):
    divs = soup.find_all('div', class_ = 'jobsearch-SerpJobCard')
    for item in divs:
        title = item.find('a').text
        company = item.find('span', class_ = 'company').text
        location = item.find(class_="recJobLoc").get('data-rc-loc')
        description = item.find('div', 'summary').text.strip()
        request_date = datetime.today().strftime('%Y-%m-%d')
        post_date = item.find('span', 'date').text.strip()
        try:
            job_salary = item.find_all('span', {'class': 'salaryText'})
        except AttributeError:
            job_salary = 'None'
        print(title)
        print(company)
        print(location)
        print(description)
        print(job_salary)
        print(post_date)
        print(request_date)
    return record

# %%
record = []

for i in range(0,40,10):
    print(f'Getting page, {i}')
    c = extract(0)
    transform(c)
# Out:
# Getting page, 0
#
# Analyst/ Junior Data Scientist
#
#
# Insurance Australia Group
# Melbourne VIC
# You will work with data scientists to produce datasets for use in analysis and model training.
# You will prototype, update and test advanced analytical models…
# []
# Today
# 2021-03-26
#
# Senior Data Scientist
#
# Flow Recruitment Australia
# Melbourne VIC
# The role will involve analysis of survey and administrative data to drive powerful business insights.
# Working in a national data science team, the role will…
# [<span class="salaryText">
# $100,000 - $140,000 a year</span>]
# Today
# 2021-03-26
#
# Data Scientist - Revenue Strategy
#
#
# Mars
# Melbourne VIC
# Understanding of statistical languages (R, Python) to manipulate data and draw insights from large data sets, able to query databases (SQL) is preferred.
# []
# 1 day ago
# 2021-03-26
#
# Technical Business Analyst/Sr Business Analyst-Data Science...
#
# Hawksworth
# Melbourne VIC
# ...
